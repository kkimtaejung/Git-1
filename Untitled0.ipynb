# %% [markdown]
# <a href="https://colab.research.google.com/github/kkimtaejung/Git-1/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 수집된 데이터 분석을 위한 pandas 임포트

# %%
import pandas as pd

# %% [markdown]
# pandas 활용해 csv 포맷으로 수집된 데이터를 데이터 프레임으로 불러오고 df라는 변수에 저장

# %%
#데이터 수집
df = pd.read_csv("https://raw.githubusercontent.com/wikibook/machine-learning/2.0/data/csv/basketball_stat.csv")

# %% [markdown]
# df.head() 명령어를 사용해 농구선수 데이터 살펴보기

# %%
df.head()
# Out:
#            Player Pos   3P   2P  TRB  AST  STL  BLK
# 0    Alex Abrines  SG  1.4  0.6  1.3  0.6  0.5  0.1
# 1    Steven Adams   C  0.0  4.7  7.7  1.1  1.1  1.0
# 2   Alexis Ajinca   C  0.0  2.3  4.5  0.3  0.5  0.6
# 3  Chris Andersen   C  0.0  0.8  2.6  0.4  0.4  0.6
# 4     Will Barton  SG  1.5  3.5  4.3  3.4  0.8  0.5

# %% [markdown]
# Pos 포지션 정보로 명령어를 통해 농구선수의 포지션 알아보기 위해, 포지션 별로 몇 개의 기존 데이터가 있는지 확인해보기

# %%
df.Pos.value_counts()
# Out:
# SG    50
# C     50
# Name: Pos, dtype: int64

# %% [markdown]
# 각 속성들이 SG와C를 구분 짓기에 필요한지, 불필요한지 데이터 시각화를 통해 살펴보기

# %%
#데이터 시각화 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# seaborn의 2차원 그래프를 사용해 데이터 시각화
#
# 결과 : 경계가 너무 급접하여 분류하기 모호하다.

# %%
#STL,2P 데이터 시각화
sns.lmplot('STL','2P',data =df, fit_reg=False, #x 축, y축, 데이터, 노 라인
           scatter_kws={"s":150}, #좌표 상의 점의 크기
           markers = ["o","x"],
           hue="Pos") #예측값
#타이틀
plt.title('STL and 2P in 2d plane')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'STL and 2P in 2d plane')

# %% [markdown]
# BLK, 3P 속성으로 데이터 시각화
#
# 결론 : 데이터 구분이 확실해 분류하기 적합하다.

# %%
# BLK, 3P 데이터 시각화
sns.lmplot('BLK','3P', data=df, fit_reg=False, #x축, y축, 데이터, 노 라인
           scatter_kws={"s":150}, #좌표 상의 점의 크기
           markers=["o","x"],
           hue="Pos")#예측값
# 타이틀
plt.title('BLK and 3P in 2d plane')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'BLK and 3P in 2d plane')

# %% [markdown]
# 데이터 다듬기
#
# 2P, AST, STL 이 분류에 도움이 안되니 없애자! 데이터 제거

# %%
df.drop(['2P','AST','STL'], axis=1, inplace = True)

# %% [markdown]
# 데이터 프레임 조회

# %%
df.head()
# Out:
#            Player Pos   3P  TRB  BLK
# 0    Alex Abrines  SG  1.4  1.3  0.1
# 1    Steven Adams   C  0.0  7.7  1.0
# 2   Alexis Ajinca   C  0.0  4.5  0.6
# 3  Chris Andersen   C  0.0  2.6  0.6
# 4     Will Barton  SG  1.5  4.3  0.5

# %% [markdown]
# 데이터 준비완료
#
# 머신러닝 모델 학습할 데이터 & 테스트할 데이터로 현재의 데이터를 나누자
#
# train_test_split 사용, 임포트먼저

# %%
#사이킷런, 한줄로 데이터 나눌수 있음
from sklearn.model_selection import train_test_split

# %% [markdown]
# 명령어 실행
#
# 80%는 학습 데이터, 20%는 테스트 데이터가 됨

# %%
train, test = train_test_split(df, test_size=0.2)

# %% [markdown]
# 데이터 개수 확인

# %%
train.shape[0]
# Out:
# 80

# %%
test.shape[0]
# Out:
# 20

# %% [markdown]
# kNN 알고리즘에서 최적의 k를 찾기위한, cross_val_score 사용
#
# 교차 검증 수행, 기존 데이터를 k개로 나눠, k번 정확도를 검증

# %%
#kNN 라이브러리 추가
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

#최적의 k를 찾기 위해 교차 검증을 수행할 k의 범위를 3부터 학습 데이터 절반까지 지정
